# %%
# simple bn for bayescard
# %load_ext sppl.magics
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
# Out:
# The sppl.magics extension is already loaded. To reload it, use:
#   %reload_ext sppl.magics

# %%
# %%sppl bn1
# dAge   ~= choice({"0":0.179, "1":0.165, "2":0.151,"3":0.135,"4":0.131,"5":0.127,"6":0.099,"7":0.013})
# if (dAge == "0"):
#     dIncome5 ~= choice({"0":1.0,"1":0.0})
# elif (dAge == "1"):
#     dIncome5 ~= choice({"0":0.982,"1":0.018})
# elif (dAge == "2"):
#     dIncome5 ~= choice({"0":0.988,"1":0.012})
# elif (dAge == "3"):
#     dIncome5 ~= choice({"0":0.853,"1":0.147})
# elif (dAge == "4"):
#     dIncome5 ~= choice({"0":0.163,"1":0.837})
# elif (dAge == "5"):
#     dIncome5 ~= choice({"0":0.975,"1":0.025})
# elif (dAge == "6"):
#     dIncome5 ~= choice({"0":0.980,"1":0.020})
# else:
#     dIncome5 ~= choice({"0":1.0,"1":0.0})

# %%
# sppl to graph
# %sppl_to_graph bn1

# %%
# bayescard simplied bn
bn1 = %sppl_get_namespace bn1

# %%
event = bn1.bn1.condition() (bn1.dIncome5 << {"1"})|(bn1.dAge << {"5"})
bn1.bn1.prob(event)
# Out:
# 0.263254

# %%
# %%sppl bn1
# dAge   ~= choice({"0":0.179, "1":0.165, "2":0.151,"3":0.135,"4":0.131,"5":0.127,"6":0.099,"7":0.013})
# if (dAge == "0"):
#     dIncome5 ~= bernoulli(p=1.0)
# elif (dAge == "1"):
#     dIncome5 ~= bernoulli(p=0.982)
# elif (dAge == "2"):
#     dIncome5 ~= bernoulli(p=0.988)
# elif (dAge == "3"):
#     dIncome5 ~= bernoulli(p=0.853)
# elif (dAge == "4"):
#     dIncome5 ~= bernoulli(p=0.163)
# elif (dAge == "5"):
#     dIncome5 ~= bernoulli(p=0.975)
# elif (dAge == "6"):
#     dIncome5 ~= bernoulli(p=0.980)
# else:
#     dIncome5 ~= bernoulli(p=1.0)

# %%
# sppl to graph
# %sppl_to_graph bn1
# bayescard simplied bn
bn1 = %sppl_get_namespace bn1

# %%
event = ((bn1.dAge << {"5"}) & (bn1.dIncome5 << {1}))
bn1.bn1.prob(event)
# Out:
# 0.123825

# %%
# %%sppl bn1
# dAge   ~= 0.179 | 0.165 | 0.151 | 0.135 | 0.127 | 0.099 | 0.013
#
# if (dAge == 0):
#     dIncome5 ~= bernoulli(p=1.0)
# elif (dAge == 1):
#     dIncome5 ~= bernoulli(p=0.982)
# elif (dAge == 2):
#     dIncome5 ~= bernoulli(p=0.988)
# elif (dAge == 3):
#     dIncome5 ~= bernoulli(p=0.853)
# elif (dAge == 4):
#     dIncome5 ~= bernoulli(p=0.163)
# elif (dAge == 5):
#     dIncome5 ~= bernoulli(p=0.975)
# elif (dAge == 6):
#     dIncome5 ~= bernoulli(p=0.980)
# else:
#     dIncome5 ~= bernoulli(p=1.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-a523a5172822> in <module>
# ----> 1 get_ipython().run_cell_magic('sppl', 'bn1', 'dAge   ~= 0.179 | 0.165 | 0.151 | 0.135 | 0.127 | 0.099 | 0.013\n\nif (dAge == 0):\n    dIncome5 ~= bernoulli(p=1.0)\nelif (dAge == 1):\n    dIncome5 ~= bernoulli(p=0.982)\nelif (dAge == 2):\n    dIncome5 ~= bernoulli(p=0.988)\nelif (dAge == 3):\n    dIncome5 ~= bernoulli(p=0.853)\nelif (dAge == 4):\n    dIncome5 ~= bernoulli(p=0.163)\nelif (dAge == 5):\n    dIncome5 ~= bernoulli(p=0.975)\nelif (dAge == 6):\n    dIncome5 ~= bernoulli(p=0.980)\nelse:\n    dIncome5 ~= bernoulli(p=1.0)\n')
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# ...

# %%
# sppl to graph
# %sppl_to_graph bn1
# bayescard simplied bn
bn1 = %sppl_get_namespace bn1
